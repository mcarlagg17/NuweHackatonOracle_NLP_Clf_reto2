# %% [markdown]
# # **EVA** TEXT CLASSIFIER
#
# ![img_ppal](https://www.innovacion-tecnologia.com/wp-content/uploads/2020/09/Historia-de-los-humanoides.jpg)

# %% [markdown]
# ## *ÍNDICE:*
# ---
# 0. INTRODUCCIÓN
# 1. **MACHINE LEARNING**
#     - 2.1. Preparación y limpieza de datos
#     - 2.2. Feature Engineering
#     - 2.3. Modelado
# 2. RESULTADOS
#     - 3.1. Visualización y reporting de los resultados
#     - 3.2. Creación de un pipeline para el flujo automatizado
# ---

# %% [markdown]
# # ***MACHINE LEARNING: NLP models training***
#
# ---

# %% [markdown]
# ### Librerías

# %%
from utils.libreries import *
from utils.functions import *

# %% [markdown]
# ### Definir constantes

# %%
REL_PATH = os.getcwd()
TRAIN_PATH = REL_PATH + '/data/raw/train.csv'
TEST_PATH = REL_PATH + '/data/raw/test.csv'
TRAIN_PROCESSED_PATH = REL_PATH + '/data/processed/train_processed.csv'

# %% [markdown]
# ### Datasets

# %%
df_train = pd.read_csv(TRAIN_PATH)
df_train.head()
# Out:
#    train_idx                                               text  label
# 0          0  i really do recommend this to anyone in need o...      1  \
# 1          1  very good every day camera fits nicely in the ...      1
# 2          2  but , dollar for dollar , this dvd player is p...      1
# 3          3  i got this phone yesterday and didn ' t find a...      1
# 4          4                            1 ) price gb of storage      1
#
#   label_text
# 0   positive
# 1   positive
# 2   positive
# 3   positive
# 4   positive

# %%
df_train.head(20)
# Out:
#     train_idx                                               text  label
# 0           0  i really do recommend this to anyone in need o...      1  \
# 1           1  very good every day camera fits nicely in the ...      1
# 2           2  but , dollar for dollar , this dvd player is p...      1
# 3           3  i got this phone yesterday and didn ' t find a...      1
# 4           4                            1 ) price gb of storage      1
# 5           5  one cabinet shop has been using one regularly ...      1
# 6           6  i will say that the os that the phone runs doe...      0
# 7           7           this model appears to be especially good      1
# 8           8  i find that it is stable in my hands and its '...      1
# 9           9  the catch is that , while it plays movies just...      0
# 10         10  cons no am fm radio tuner something a large nu...      0
# 11         11  you can move the focus range to almost anywher...      1
# 12         12  this is only a problem at night , during the d...      0
# 13         13  for my first i had a diaper genie which was no...      0
# 14         14                  the tech support is worthless too      0
# 15         15  the navigation takes so much time that it woul...      0
# 16         16  it does n ' t have firewire , not a real compl...      0
# 17         17  i love the rounded edges now , fits so much be...      1
# 18         18  this thing does everything but washes your dishes      1
# 19         19  unfortunately , after loading 280 songs , all ...      0
#
#    label_text
# 0    positive
# 1    positive
# 2    positive
# 3    positive
# 4    positive
# 5    positive
# 6    negative
# 7    positive
# 8    positive
# 9    negative
# 10   negative
# 11   positive
# 12   negative
# 13   negative
# 14   negative
# 15   negative
# 16   negative
# 17   positive
# 18   positive
# 19   negative

# %%
ds_test = pd.read_csv(TEST_PATH)
ds_test.head()
# Out:
#    test_idx                                               text
# 0         0                            fm receiver it has none
# 1         1  the picture quality surprised me , when i firs...
# 2         2  great video clip quality for a digital camera ...
# 3         3  creative did well on its rechargeable battery ...
# 4         4  i highly recommend this camera to anyone looki...

# %% [markdown]
# ### Baseline de los modelos:

# %%
df_train['text'] = df_train['text'].apply(preprocess_text)
df_train['text']
# Out:
# 0                 really recommend anyone need new player
# 1       good every day camera fit nicely pocket jean t...
# 2                  dollar dollar dvd player probably best
# 3                    got phone yesterday find problem yet
# 4                                      1 price gb storage
#                               ...
# 3011    itunes find good window medium player computer...
# 3012          played feature yet camera easy use get used
# 3013    application lot application work well eventual...
# 3014                                    battery non issue
# 3015     fm tuner 5g storage removable disk great feature
# Name: text, Length: 3016, dtype: object

# %%
plt.figure(figsize=(10,8))
plt.style.use('ggplot')

# %%
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
from scipy.special import softmax
import tensorflow as tf
# Out:
# Canceled future for execute_request message before replies were done
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)

# %%
model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
model.save_pretrained(MODEL)

text = "Good night 😊"
encoded_input = tokenizer(text, return_tensors='tf')
output = model(encoded_input)
scores = output[0][0].numpy()
scores = softmax(scores)
# Out:
# Canceled future for execute_request message before replies were done
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %% [markdown]
# ### Modelos modificando parametros:

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df_train['text'])
y = df_train['label'].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 77)

# %%
models_names = list(choose_models('all',params=None).keys())
#mods = models_names
mods = models_names[0]
print(mods)

models_generator(X,y,choose_models(mods,params=None),choose_params(mods),
file_name ='metrics.csv',dir_file='model/model_metrics',dir_model_file='model',scaling=False,
scoring = { "AUC": "roc_auc","Accuracy": make_scorer(accuracy_score),'Precision': make_scorer(precision_score),'F1':make_scorer(f1_score)})

# %%
models_names = list(choose_models('all',params=None).keys())
#mods = models_names
mods = models_names[3:5]
print(mods)
for mod in mods:  
    models_generator(X,y,choose_models(mod,params=None),choose_params(mod),
    file_name ='metrics.csv',dir_file='model/model_metrics',dir_model_file='model',scaling=False,
    scoring = { "AUC": "roc_auc","Accuracy": make_scorer(accuracy_score),'Precision': make_scorer(precision_score),'F1':make_scorer(f1_score)})

# %%
x=pd.read_csv(os.getcwd()+'/model/model_metrics/metrics.csv',sep=';')
x.sort_values(by='F1',ascending = False)
# Out:
#                     model                                       params_tried  \
# 0      LogisticRegression  {'penalty': ['l2'], 'class_weight': ['none', '...
# 4           XGBClassifier  {'nthread': [4], 'objective': ['binary:logisti...
# 5                     SVC  [{'C': [1, 10, 100, 1000], 'kernel': ['linear'...
# 1    KNeighborsClassifier  {'n_neighbors': [3, 5, 7, 9, 11, 13, 15], 'wei...
# 6      LogisticRegression  {'penalty': ['l1', 'l2'], 'C': [0.01, 0.1, 1, ...
# 7      LogisticRegression  {'penalty': ['l1', 'l2'], 'C': [0.01, 0.1, 1, ...
# 3     ExtraTreeClassifier  {'criterion': ['gini', 'entropy'], 'max_depth'...
# 2  DecisionTreeClassifier  {'criterion': ['log_loss', 'gini', 'entropy'],...
#
#                                          best_params       ACC  Precision  \
# 0  {'class_weight': 'none', 'max_iter': 50, 'pena...  0.776490   0.784067
# 4  {'colsample_bytree': 1.0, 'learning_rate': 0.0...  0.764901   0.760870
# 5  {'C': 1, 'class_weight': 'balanced', 'kernel':...  0.788079   0.854592
# 1  {'algorithm': 'ball_tree', 'leaf_size': 20, 'n...  0.740066   0.741748
# 6  {'C': 0.01, 'max_iter': 100, 'penalty': 'l1', ...  0.672185   0.672185
# 7  {'C': 0.01, 'max_iter': 100, 'penalty': 'l1', ...  0.672185   0.672185
# 3  {'class_weight': None, 'criterion': 'gini', 'm...  0.665563   0.674658
# 2  {'class_weight': 'balanced', 'criterion': 'log...  0.652318   0.750000
#
#      Recall        F1       ROC   Jaccard                        model_path
# 0  0.921182  0.847112  0.700490  0.734774      model/LogisticRegression.pkl
# 4  0.948276  0.844298  0.668582  0.730550           model/XGBClassifier.pkl
# 5  0.825123  0.839599  0.768622  0.723542                     model/SVC.pkl
# 1  0.940887  0.829533  0.634585  0.708720    model/KNeighborsClassifier.pkl
# 6  1.000000  0.803960  0.500000  0.672185    model/LogisticRegression_1.pkl
# 7  1.000000  0.803960  0.500000  0.672185    model/LogisticRegression_2.pkl
# 3  0.970443  0.795960  0.505424  0.661074     model/ExtraTreeClassifier.pkl
# 2  0.724138  0.736842  0.614594  0.583333  model/DecisionTreeClassifier.pkl

# %% [markdown]
# ### Resultado con modelo elegido:

# %%
df_test = ds_test.copy()
df_test['text'] = ds_test['text'].apply(preprocess_text)

# %%
df_test.head()
# Out:
#    test_idx                                               text
# 0         0                                   fm receiver none
# 1         1  picture quality surprised first saw camera saw...
# 2         2  great video clip quality digital camera much b...
# 3         3         creative well rechargeable battery feature
# 4         4  highly recommend camera anyone looking good di...

# %%
ds_test.head()
# Out:
#    test_idx                                               text
# 0         0                            fm receiver it has none
# 1         1  the picture quality surprised me , when i firs...
# 2         2  great video clip quality for a digital camera ...
# 3         3  creative did well on its rechargeable battery ...
# 4         4  i highly recommend this camera to anyone looki...

# %%
model_path='model/LogisticRegression.pkl'
model=pickle.load(open(model_path,'rb'))

# %%
model
# Out:
# LogisticRegression(class_weight='none', max_iter=50, solver='newton-cg')

# %%
test_X = vectorizer.transform(df_test['text'])
df_test['prediction']=model.predict(test_X)

# %%
df_test.head()
# Out:
#    test_idx                                               text  prediction
# 0         0                                   fm receiver none           0
# 1         1  picture quality surprised first saw camera saw...           1
# 2         2  great video clip quality digital camera much b...           1
# 3         3         creative well rechargeable battery feature           1
# 4         4  highly recommend camera anyone looking good di...           1

# %%
prediction_json={'target':{str(df_test['test_idx'][i]):int(df_test['prediction'][i]) for i in range(len(df_test))}}

# %%
prediction_json
# Out:
# {'target': {'0': 0,
#   '1': 1,
#   '2': 1,
#   '3': 1,
#   '4': 1,
#   '5': 0,
#   '6': 1,
#   '7': 1,
#   '8': 1,
#   '9': 1,
#   '10': 0,
#   '11': 0,
#   '12': 1,
#   '13': 1,
#   '14': 1,
#   '15': 1,
#   '16': 0,
#   '17': 0,
#   '18': 1,
#   '19': 0,
#   '20': 1,
#   '21': 1,
#   '22': 1,
#   '23': 1,
#   '24': 1,
#   '25': 1,
#   '26': 1,
#   '27': 1,
#   '28': 1,
#   '29': 1,
#   '30': 0,
#   '31': 1,
#   '32': 1,
#   '33': 1,
#   '34': 0,
#   '35': 1,
#   '36': 1,
#   '37': 1,
#   '38': 1,
#   '39': 0,
#   '40': 0,
#   '41': 0,
#   '42': 0,
#   '43': 0,
#   '44': 1,
#   '45': 1,
#   '46': 1,
#   '47': 1,
#   '48': 0,
#   '49': 1,
#   '50': 0,
#   '51': 0,
#   '52': 1,
#   '53': 1,
#   '54': 0,
#   '55': 0,
#   '56': 1,
#   '57': 0,
#   '58': 1,
#   '59': 0,
#   '60': 0,
#   '61': 1,
#   '62': 0,
#   '63': 1,
#   '64': 0,
#   '65': 1,
#   '66': 1,
#   '67': 1,
#   '68': 1,
#   '69': 1,
#   '70': 1,
#   '71': 1,
#   '72': 1,
#   '73': 0,
#   '74': 1,
#   '75': 1,
#   '76': 1,
#   '77': 0,
#   '78': 1,
#   '79': 1,
#   '80': 1,
#   '81': 0,
#   '82': 1,
#   '83': 0,
#   '84': 1,
#   '85': 1,
#   '86': 1,
#   '87': 1,
#   '88': 1,
#   '89': 1,
#   '90': 1,
#   '91': 1,
#   '92': 1,
#   '93': 1,
#   '94': 1,
#   '95': 0,
#   '96': 1,
#   '97': 1,
#   '98': 0,
#   '99': 1,
#   '100': 1,
#   '101': 1,
#   '102': 1,
#   '103': 1,
#   '104': 0,
#   '105': 1,
#   '106': 0,
#   '107': 0,
#   '108': 1,
#   '109': 1,
#   '110': 1,
#   '111': 0,
#   '112': 1,
#   '113': 1,
#   '114': 0,
#   '115': 0,
#   '116': 1,
#   '117': 1,
#   '118': 1,
#   '119': 1,
#   '120': 0,
#   '121': 1,
#   '122': 1,
#   '123': 1,
#   '124': 1,
#   '125': 0,
#   '126': 1,
#   '127': 1,
#   '128': 0,
#   '129': 1,
#   '130': 1,
#   '131': 0,
#   '132': 0,
#   '133': 1,
#   '134': 1,
#   '135': 0,
#   '136': 1,
#   '137': 1,
#   '138': 1,
#   '139': 1,
#   '140': 1,
#   '141': 0,
#   '142': 1,
#   '143': 0,
#   '144': 1,
#   '145': 1,
#   '146': 0,
#   '147': 1,
#   '148': 0,
#   '149': 1,
#   '150': 1,
#   '151': 1,
#   '152': 1,
#   '153': 1,
#   '154': 1,
#   '155': 1,
#   '156': 1,
#   '157': 1,
#   '158': 1,
#   '159': 0,
#   '160': 1,
#   '161': 0,
#   '162': 0,
#   '163': 0,
#   '164': 1,
#   '165': 0,
#   '166': 1,
#   '167': 0,
#   '168': 1,
#   '169': 1,
#   '170': 1,
#   '171': 1,
#   '172': 1,
#   '173': 1,
#   '174': 1,
#   '175': 0,
#   '176': 0,
#   '177': 1,
#   '178': 1,
#   '179': 1,
#   '180': 1,
#   '181': 1,
#   '182': 1,
#   '183': 0,
#   '184': 1,
#   '185': 1,
#   '186': 1,
#   '187': 1,
#   '188': 1,
#   '189': 1,
#   '190': 1,
#   '191': 1,
#   '192': 0,
#   '193': 1,
#   '194': 1,
#   '195': 1,
#   '196': 1,
#   '197': 0,
#   '198': 1,
#   '199': 1,
#   '200': 1,
#   '201': 0,
#   '202': 1,
#   '203': 1,
#   '204': 1,
#   '205': 1,
#   '206': 0,
#   '207': 1,
#   '208': 1,
#   '209': 1,
#   '210': 1,
#   '211': 0,
#   '212': 1,
#   '213': 0,
#   '214': 1,
#   '215': 1,
#   '216': 1,
#   '217': 1,
#   '218': 0,
#   '219': 1,
#   '220': 0,
#   '221': 1,
#   '222': 0,
#   '223': 1,
#   '224': 1,
#   '225': 1,
#   '226': 1,
#   '227': 0,
#   '228': 1,
#   '229': 1,
#   '230': 1,
#   '231': 1,
#   '232': 1,
#   '233': 0,
#   '234': 1,
#   '235': 1,
#   '236': 1,
#   '237': 1,
#   '238': 1,
#   '239': 1,
#   '240': 1,
#   '241': 1,
#   '242': 1,
#   '243': 0,
#   '244': 1,
#   '245': 1,
#   '246': 1,
#   '247': 1,
#   '248': 1,
#   '249': 1,
#   '250': 1,
#   '251': 1,
#   '252': 1,
#   '253': 0,
#   '254': 1,
#   '255': 0,
#   '256': 1,
#   '257': 0,
#   '258': 1,
#   '259': 1,
#   '260': 1,
#   '261': 1,
#   '262': 1,
#   '263': 1,
#   '264': 0,
#   '265': 0,
#   '266': 1,
#   '267': 1,
#   '268': 1,
#   '269': 0,
#   '270': 1,
#   '271': 1,
#   '272': 1,
#   '273': 0,
#   '274': 0,
#   '275': 1,
#   '276': 0,
#   '277': 1,
#   '278': 1,
#   '279': 1,
#   '280': 1,
#   '281': 1,
#   '282': 0,
#   '283': 0,
#   '284': 0,
#   '285': 1,
#   '286': 1,
#   '287': 0,
#   '288': 1,
#   '289': 1,
#   '290': 1,
#   '291': 1,
#   '292': 1,
#   '293': 1,
#   '294': 1,
#   '295': 0,
#   '296': 1,
#   '297': 1,
#   '298': 1,
#   '299': 1,
#   '300': 1,
#   '301': 0,
#   '302': 1,
#   '303': 1,
#   '304': 1,
#   '305': 1,
#   '306': 1,
#   '307': 0,
#   '308': 0,
#   '309': 1,
#   '310': 1,
#   '311': 1,
#   '312': 1,
#   '313': 1,
#   '314': 1,
#   '315': 1,
#   '316': 1,
#   '317': 0,
#   '318': 1,
#   '319': 1,
#   '320': 1,
#   '321': 0,
#   '322': 1,
#   '323': 1,
#   '324': 1,
#   '325': 0,
#   '326': 1,
#   '327': 1,
#   '328': 1,
#   '329': 1,
#   '330': 1,
#   '331': 1,
#   '332': 1,
#   '333': 1,
#   '334': 1,
#   '335': 0,
#   '336': 0,
#   '337': 1,
#   '338': 1,
#   '339': 0,
#   '340': 1,
#   '341': 1,
#   '342': 0,
#   '343': 1,
#   '344': 1,
#   '345': 0,
#   '346': 1,
#   '347': 1,
#   '348': 1,
#   '349': 1,
#   '350': 1,
#   '351': 1,
#   '352': 1,
#   '353': 1,
#   '354': 1,
#   '355': 1,
#   '356': 0,
#   '357': 1,
#   '358': 0,
#   '359': 1,
#   '360': 0,
#   '361': 1,
#   '362': 1,
#   '363': 1,
#   '364': 1,
#   '365': 1,
#   '366': 1,
#   '367': 0,
#   '368': 1,
#   '369': 0,
#   '370': 1,
#   '371': 1,
#   '372': 1,
#   '373': 1,
#   '374': 1,
#   '375': 1,
#   '376': 0,
#   '377': 1,
#   '378': 0,
#   '379': 1,
#   '380': 1,
#   '381': 1,
#   '382': 0,
#   '383': 1,
#   '384': 1,
#   '385': 1,
#   '386': 1,
#   '387': 1,
#   '388': 1,
#   '389': 1,
#   '390': 1,
#   '391': 1,
#   '392': 1,
#   '393': 1,
#   '394': 1,
#   '395': 0,
#   '396': 0,
#   '397': 1,
#   '398': 1,
#   '399': 1,
#   '400': 1,
#   '401': 0,
#   '402': 0,
#   '403': 0,
#   '404': 1,
#   '405': 1,
#   '406': 1,
#   '407': 1,
#   '408': 1,
#   '409': 1,
#   '410': 1,
#   '411': 1,
#   '412': 1,
#   '413': 1,
#   '414': 1,
#   '415': 1,
#   '416': 1,
#   '417': 1,
#   '418': 1,
#   '419': 1,
#   '420': 1,
#   '421': 1,
#   '422': 1,
#   '423': 1,
#   '424': 1,
#   '425': 0,
#   '426': 1,
#   '427': 1,
#   '428': 0,
#   '429': 0,
#   '430': 1,
#   '431': 1,
#   '432': 1,
#   '433': 1,
#   '434': 1,
#   '435': 1,
#   '436': 0,
#   '437': 1,
#   '438': 1,
#   '439': 1,
#   '440': 1,
#   '441': 1,
#   '442': 1,
#   '443': 1,
#   '444': 1,
#   '445': 1,
#   '446': 0,
#   '447': 1,
#   '448': 1,
#   '449': 1,
#   '450': 1,
#   '451': 1,
#   '452': 1,
#   '453': 1,
#   '454': 1,
#   '455': 1,
#   '456': 0,
#   '457': 1,
#   '458': 1,
#   '459': 1,
#   '460': 1,
#   '461': 0,
#   '462': 1,
#   '463': 1,
#   '464': 1,
#   '465': 1,
#   '466': 1,
#   '467': 1,
#   '468': 1,
#   '469': 1,
#   '470': 1,
#   '471': 1,
#   '472': 1,
#   '473': 1,
#   '474': 0,
#   '475': 1,
#   '476': 1,
#   '477': 1,
#   '478': 1,
#   '479': 1,
#   '480': 1,
#   '481': 1,
#   '482': 1,
#   '483': 1,
#   '484': 1,
#   '485': 1,
#   '486': 0,
#   '487': 1,
#   '488': 0,
#   '489': 1,
#   '490': 1,
#   '491': 1,
#   '492': 1,
#   '493': 1,
#   '494': 1,
#   '495': 0,
#   '496': 1,
#   '497': 1,
#   '498': 1,
#   '499': 0,
#   '500': 1,
#   '501': 1,
#   '502': 1,
#   '503': 1,
#   '504': 0,
#   '505': 1,
#   '506': 0,
#   '507': 1,
#   '508': 1,
#   '509': 1,
#   '510': 1,
#   '511': 1,
#   '512': 0,
#   '513': 1,
#   '514': 1,
#   '515': 1,
#   '516': 1,
#   '517': 1,
#   '518': 1,
#   '519': 1,
#   '520': 1,
#   '521': 0,
#   '522': 0,
#   '523': 1,
#   '524': 1,
#   '525': 1,
#   '526': 1,
#   '527': 1,
#   '528': 1,
#   '529': 1,
#   '530': 1,
#   '531': 1,
#   '532': 1,
#   '533': 1,
#   '534': 1,
#   '535': 0,
#   '536': 1,
#   '537': 1,
#   '538': 1,
#   '539': 1,
#   '540': 1,
#   '541': 1,
#   '542': 1,
#   '543': 1,
#   '544': 0,
#   '545': 1,
#   '546': 0,
#   '547': 1,
#   '548': 1,
#   '549': 1,
#   '550': 1,
#   '551': 1,
#   '552': 1,
#   '553': 1,
#   '554': 1,
#   '555': 0,
#   '556': 1,
#   '557': 1,
#   '558': 1,
#   '559': 1,
#   '560': 0,
#   '561': 1,
#   '562': 1,
#   '563': 1,
#   '564': 1,
#   '565': 1,
#   '566': 1,
#   '567': 1,
#   '568': 1,
#   '569': 1,
#   '570': 1,
#   '571': 1,
#   '572': 1,
#   '573': 1,
#   '574': 0,
#   '575': 1,
#   '576': 1,
#   '577': 1,
#   '578': 1,
#   '579': 1,
#   '580': 1,
#   '581': 1,
#   '582': 1,
#   '583': 1,
#   '584': 1,
#   '585': 1,
#   '586': 0,
#   '587': 1,
#   '588': 0,
#   '589': 1,
#   '590': 1,
#   '591': 1,
#   '592': 1,
#   '593': 1,
#   '594': 1,
#   '595': 1,
#   '596': 0,
#   '597': 1,
#   '598': 1,
#   '599': 1,
#   '600': 0,
#   '601': 1,
#   '602': 0,
#   '603': 1,
#   '604': 1,
#   '605': 1,
#   '606': 1,
#   '607': 1,
#   '608': 1,
#   '609': 1,
#   '610': 1,
#   '611': 0,
#   '612': 0,
#   '613': 1,
#   '614': 1,
#   '615': 1,
#   '616': 1,
#   '617': 1,
#   '618': 1,
#   '619': 1,
#   '620': 1,
#   '621': 1,
#   '622': 1,
#   '623': 1,
#   '624': 1,
#   '625': 1,
#   '626': 1,
#   '627': 1,
#   '628': 1,
#   '629': 0,
#   '630': 1,
#   '631': 1,
#   '632': 0,
#   '633': 0,
#   '634': 1,
#   '635': 1,
#   '636': 1,
#   '637': 0,
#   '638': 1,
#   '639': 0,
#   '640': 1,
#   '641': 1,
#   '642': 1,
#   '643': 1,
#   '644': 1,
#   '645': 1,
#   '646': 0,
#   '647': 1,
#   '648': 1,
#   '649': 1,
#   '650': 1,
#   '651': 0,
#   '652': 1,
#   '653': 1,
#   '654': 1,
#   '655': 1,
#   '656': 1,
#   '657': 1,
#   '658': 1,
#   '659': 1,
#   '660': 1,
#   '661': 1,
#   '662': 1,
#   '663': 1,
#   '664': 1,
#   '665': 1,
#   '666': 0,
#   '667': 1,
#   '668': 1,
#   '669': 1,
#   '670': 1,
#   '671': 1,
#   '672': 1,
#   '673': 1,
#   '674': 1,
#   '675': 1,
#   '676': 1,
#   '677': 1,
#   '678': 1,
#   '679': 1,
#   '680': 1,
#   '681': 1,
#   '682': 1,
#   '683': 1,
#   '684': 1,
#   '685': 1,
#   '686': 0,
#   '687': 1,
#   '688': 1,
#   '689': 1,
#   '690': 1,
#   '691': 1,
#   '692': 0,
#   '693': 1,
#   '694': 0,
#   '695': 1,
#   '696': 0,
#   '697': 0,
#   '698': 1,
#   '699': 1,
#   '700': 0,
#   '701': 1,
#   '702': 1,
#   '703': 1,
#   '704': 1,
#   '705': 0,
#   '706': 1,
#   '707': 1,
#   '708': 1,
#   '709': 0,
#   '710': 1,
#   '711': 1,
#   '712': 0,
#   '713': 1,
#   '714': 1,
#   '715': 0,
#   '716': 1,
#   '717': 1,
#   '718': 0,
#   '719': 1,
#   '720': 1,
#   '721': 1,
#   '722': 0,
#   '723': 0,
#   '724': 1,
#   '725': 1,
#   '726': 1,
#   '727': 1,
#   '728': 1,
#   '729': 0,
#   '730': 1,
#   '731': 1,
#   '732': 1,
#   '733': 1,
#   '734': 0,
#   '735': 1,
#   '736': 1,
#   '737': 1,
#   '738': 0,
#   '739': 1,
#   '740': 1,
#   '741': 1,
#   '742': 1,
#   '743': 1,
#   '744': 1,
#   '745': 0,
#   '746': 1,
#   '747': 1,
#   '748': 1,
#   '749': 1,
#   '750': 1,
#   '751': 0,
#   '752': 1,
#   '753': 1}}

# %%
type(prediction_json)
# Out:
# dict

# %%
with open("data/processed/prediction.json", "w") as f:
    json.dump(prediction_json, f)

# %% [markdown]
# ## OBSERVACIONES:
# - F1-score probado en la web = 0.70
